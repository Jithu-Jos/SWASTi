# %%
# !pip3 install ai.cs
# !pip3 install ai.fri3d

# %%
import numpy as np
from ai import cs
from ai.fri3d.model import StaticFRi3D
from astropy import units as u
from matplotlib import pyplot as plt
from PIL import Image
#from mpl_toolkits.mplot3d import proj3d

# %%
#%% PLUTO setup

v_unit = 250.0                #km/s
l_unit = u.au.to(u.km, 1)   #in km
t_unit = l_unit/v_unit      #in sec

dt = t_unit*1.88e-4          #aprrox value in sec: has to be greater than the real g_dt
theta_res = 2.0               #in degree
phi_res = 2.0                 #in degree
#v_cme = 1000.0                #velocity of injecting CME in km/s


cme_phi = u.deg.to(u.rad, 9.0+180)
cme_theta = u.deg.to(u.rad, -7.0)  



hw_rad = u.deg.to(u.rad, 43.0)
hh_rad = u.deg.to(u.rad, 43.0)
v_t = 870    #v_cme/(1 + np.tan(hh_rad))

# %%
time = dt*np.arange(0, 240, 1)
radius = 0.081 + u.km.to(u.au, v_t*time)
cr = 2284
output_dir = f"Input/CME1"
input_dir = f"Input/CME1/"
output_dir_gif = f"{cr}/Input_gif/CME_trial_periodic_new/"
outputgif = f"{cr}/Input_gif/CME_trial_periodic_new/Input.gif"

# %%
for i in range (0, len(radius)):
    sfr = StaticFRi3D(toroidal_height=u.au.to(u.m, radius[i]),
        # poloidal_height=u.au.to(u.m, 0.4),
        latitude=cme_theta,
        longitude=cme_phi,
        half_width=hw_rad,
        half_height=hh_rad,
        pancaking=0.6,
        tilt = u.deg.to(u.rad, 0),
        chirality=-1.0,
        polarity=-1.0,
        flattening=0.5,
        flux=5e12,
        twist=2)
    
    _phi = np.linspace(-u.deg.to(u.rad, 90) + cme_phi, u.deg.to(u.rad, 90) + cme_phi, 181)
    _theta = np.linspace(-u.deg.to(u.rad, 60) + cme_theta, u.deg.to(u.rad, 60) + cme_theta, 121)
    _r = u.au.to(u.m, 0.1)
    
    r, theta, phi = np.meshgrid(_r, _theta, _phi)
    
    x, y, z = cs.sp2cart(r.flatten(), theta.flatten(), phi.flatten())
    
    b, v = sfr.data(x, y, z)
    b *= 1e9
    
    B_mag = np.sqrt(b[:,0]**2 + b[:,1]**2 + b[:,2]**2)
    
    m = np.logical_and(B_mag>0, radius[i]>0.08)
    
    vr = v_t * (v[m,0] + v[m,1]*np.cos(phi.flatten()[m]))

    print("\nSlice number : ", i)
    print('No. of points = "', len(x[m]),'" at', radius[i], 'AU')
    print('Vr = ', np.max(vr))                     #toroidal component
    #print('V_p = ', np.mean(v[m,1])*velocity)                     #poloidal component
    
    theta_pluto = u.deg.to(u.rad, 90) - theta.flatten()[m]
    phi_pluto = u.deg.to(u.rad, 180) + phi.flatten()[m]  
    # phi_pluto = u.deg.to(u.rad) + phi.flatten()[m]
    
#     phi_pluto = np.mod(phi_pluto, 2*np.pi)   # To make sure phi is in the range 0 to 2*pi
    phi_pluto = np.where(phi_pluto == 2*np.pi, 2*np.pi, np.mod(phi_pluto, 2*np.pi))

#     theta_pluto = np.mod(theta_pluto, np.pi) ##############
#     phi_pluto = np.where(phi_pluto > 2*np.pi,phi_pluto - 2*np.pi,phi_pluto)
#     phi_pluto = np.where(phi_pluto < 0,phi_pluto + 2*np.pi,phi_pluto)
    
    sin_t = np.sin(theta_pluto)
    sin_p = np.sin(phi_pluto)
    cos_t = np.cos(theta_pluto)
    cos_p = np.cos(phi_pluto)
    
    Br = b[m,0]*sin_t*cos_p + b[m,1]*sin_t*sin_p + b[m,2]*cos_t
    Bt = b[m,0]*cos_t*cos_p + b[m,1]*cos_t*sin_p - b[m,2]*sin_t
    Bp = -1*b[m,0]*sin_p + b[m,1]*cos_p
    Vr = vr
    
    fg1 = open(f"{output_dir}/FR_Br_"+str(i)+".txt", "w")
    fg2 = open(f"{output_dir}/FR_Bt_"+str(i)+".txt", "w")
    fg3 = open(f"{output_dir}/FR_Bp_"+str(i)+".txt", "w")
    fg4 = open(f"{output_dir}/FR_Vr_"+str(i)+".txt", "w")
    fg5 = open(f"{output_dir}/FR_theta_"+str(i)+".txt", "w")
    fg6 = open(f"{output_dir}/FR_phi_"+str(i)+".txt", "w")
    
    for j in range(0, len(Br)):
        
        fg1.write("%lf\n"%(Br[j]))
        fg2.write("%lf\n"%(Bt[j]))
        fg3.write("%lf\n"%(Bp[j]))
        fg4.write("%lf\n"%(Vr[j]))
        fg5.write("%lf\n"%(theta_pluto[j]))
        fg6.write("%lf\n"%(phi_pluto[j]))
        
    fg1.close()
    fg2.close()
    fg3.close()
    fg4.close()
    fg5.close()
    fg6.close()
# Out:
# Slice number :  0
# No. of points = " 5699 " at 0.081 AU
# Vr =  740.5897111800452
#
# Slice number :  1
# No. of points = " 5893 " at 0.08165424 AU
# Vr =  746.0103960077528
#
# Slice number :  2
# No. of points = " 6077 " at 0.08230848 AU
# Vr =  751.3716759166629
#
# Slice number :  3
# No. of points = " 6245 " at 0.08296272 AU
# Vr =  756.6496778529261
#
# Slice number :  4
# No. of points = " 6447 " at 0.08361696 AU
# Vr =  761.843521209532
#
# Slice number :  5
# No. of points = " 6623 " at 0.0842712 AU
# Vr =  766.9580453454244
#
# Slice number :  6
# No. of points = " 6817 " at 0.08492544 AU
# Vr =  771.9937129580558
#
# Slice number :  7
# No. of points = " 6987 " at 0.08557968 AU
# Vr =  776.952339772136
#
# Slice number :  8
# No. of points = " 7183 " at 0.08623392 AU
# Vr =  781.8356877810157
#
# Slice number :  9
# No. of points = " 7359 " at 0.08688816 AU
# Vr =  786.6454674771
#
# Slice number :  10
# No. of points = " 7543 " at 0.0875424 AU
# Vr =  791.3833400148033
#
# Slice number :  11
# No. of points = " 7715 " at 0.08819664 AU
# Vr =  796.0485317892654
#
# Slice number :  12
# No. of points = " 7891 " at 0.08885088000000001 AU
# Vr =  800.6472020670235
#
# Slice number :  13
# No. of points = " 8059 " at 0.08950512000000001 AU
# Vr =  805.1786556590241
#
# Slice number :  14
# No. of points = " 8233 " at 0.09015936000000001 AU
# Vr =  809.6541955228149
#
# Slice number :  15
# No. of points = " 8415 " at 0.09081360000000001 AU
# Vr =  814.0720350884609
#
# Slice number :  16
# No. of points = " 8591 " at 0.09146784 AU
# Vr =  818.4266758872568
#
# Slice number :  17
# No. of points = " 8747 " at 0.09212208 AU
# Vr =  822.7194644094465
#
# Slice number :  18
# No. of points = " 8917 " at 0.09277632 AU
# Vr =  826.9517091589825
#
# Slice number :  19
# No. of points = " 9089 " at 0.09343056 AU
# Vr =  831.1246820057912
#
# Slice number :  20
# No. of points = " 9251 " at 0.0940848 AU
# Vr =  835.2396194260932
#
# Slice number :  21
# No. of points = " 9415 " at 0.09473904 AU
# Vr =  839.2977237415289
#
# Slice number :  22
# No. of points = " 9535 " at 0.09539328 AU
# Vr =  843.3001643004666
#
# Slice number :  23
# No. of points = " 9685 " at 0.09604752 AU
# Vr =  847.2480785853583
#
# Slice number :  24
# No. of points = " 9807 " at 0.09670176 AU
# Vr =  851.1425732958996
#
# Slice number :  25
# No. of points = " 9937 " at 0.097356 AU
# Vr =  854.9847253833503
#
# Slice number :  26
# No. of points = " 10057 " at 0.09801024 AU
# Vr =  858.7755830434235
#
# Slice number :  27
# No. of points = " 10177 " at 0.09866448 AU
# Vr =  862.5161666696632
#
# Slice number :  28
# No. of points = " 10279 " at 0.09931872 AU
# Vr =  866.2074697691503
#
# Slice number :  29
# No. of points = " 10401 " at 0.09997296 AU
# Vr =  869.8504598422545
#
# Slice number :  30
# No. of points = " 10501 " at 0.1006272 AU
# Vr =  873.4460792280547
#
# Slice number :  31
# No. of points = " 10599 " at 0.10128144 AU
# Vr =  876.9952459170058
#
# Slice number :  32
# No. of points = " 10723 " at 0.10193568 AU
# Vr =  880.4988543323117
#
# Slice number :  33
# No. of points = " 10803 " at 0.10258992 AU
# Vr =  883.9577760813848
#
# Slice number :  34
# No. of points = " 10907 " at 0.10324416 AU
# Vr =  887.3728606787496
#
# Slice number :  35
# No. of points = " 10999 " at 0.1038984 AU
# Vr =  890.7449362416291
#
# Slice number :  36
# No. of points = " 11085 " at 0.10455264 AU
# Vr =  894.0748101594114
#
# Slice number :  37
# No. of points = " 11173 " at 0.10520688 AU
# Vr =  897.3632697381471
#
# Slice number :  38
# No. of points = " 11271 " at 0.10586112 AU
# Vr =  900.6110828211322
#
# Slice number :  39
# No. of points = " 11353 " at 0.10651536 AU
# Vr =  903.8189983866374
#
# Slice number :  40
# No. of points = " 11431 " at 0.1071696 AU
# Vr =  906.9877471237323
#
# Slice number :  41
# No. of points = " 11511 " at 0.10782384 AU
# Vr =  910.1180419871589
#
# Slice number :  42
# No. of points = " 11599 " at 0.10847808 AU
# Vr =  913.2105787320991
#
# Slice number :  43
# No. of points = " 11685 " at 0.10913232 AU
# Vr =  916.2660364297461
#
# Slice number :  44
# No. of points = " 11741 " at 0.10978656 AU
# Vr =  919.285077970244
#
# Slice number :  45
# No. of points = " 11833 " at 0.1104408 AU
# Vr =  922.268350535641
#
# Slice number :  46
# No. of points = " 11913 " at 0.11109504 AU
# Vr =  925.21648604715
#
# Slice number :  47
# No. of points = " 11961 " at 0.11174928 AU
# Vr =  928.1301016380394
#
# Slice number :  48
# No. of points = " 12049 " at 0.11240352 AU
# Vr =  931.0098000735838
#
# Slice number :  49
# No. of points = " 12121 " at 0.11305776000000001 AU
# Vr =  933.8561701667858
#
# Slice number :  50
# No. of points = " 12185 " at 0.11371200000000001 AU
# Vr =  936.6697871797467
#
# Slice number :  51
# No. of points = " 12249 " at 0.11436624000000001 AU
# Vr =  939.4512132112615
#
# Slice number :  52
# No. of points = " 12329 " at 0.11502048000000001 AU
# Vr =  942.2009975711837
#
# Slice number :  53
# No. of points = " 12373 " at 0.11567472 AU
# Vr =  944.9196771420906
#
# Slice number :  54
# No. of points = " 12445 " at 0.11632896 AU
# Vr =  947.6077767287375
#
# Slice number :  55
# No. of points = " 12529 " at 0.11698320000000001 AU
# Vr =  950.265809395793
#
# Slice number :  56
# No. of points = " 12579 " at 0.11763744000000001 AU
# Vr =  952.8942767943001
#
# Slice number :  57
# No. of points = " 12625 " at 0.11829168000000001 AU
# Vr =  955.4936694773033
#
# Slice number :  58
# No. of points = " 12683 " at 0.11894592 AU
# Vr =  958.0644672050645
#
# Slice number :  59
# No. of points = " 12771 " at 0.11960016 AU
# Vr =  960.6071392402546
#
# Slice number :  60
# No. of points = " 12813 " at 0.12025440000000001 AU
# Vr =  963.1221446335136
#
# Slice number :  61
# No. of points = " 12861 " at 0.12090864 AU
# Vr =  965.6099324997393
#
# Slice number :  62
# No. of points = " 12917 " at 0.12156288 AU
# Vr =  968.0709422854522
#
# Slice number :  63
# No. of points = " 12989 " at 0.12221712 AU
# Vr =  970.505604027575
#
# Slice number :  64
# No. of points = " 13041 " at 0.12287136 AU
# Vr =  972.914338603944
#
# Slice number :  65
# No. of points = " 13081 " at 0.1235256 AU
# Vr =  975.2975579758589
#
# Slice number :  66
# No. of points = " 13133 " at 0.12417984 AU
# Vr =  977.6556654229676
#
# Slice number :  67
# No. of points = " 13199 " at 0.12483408 AU
# Vr =  979.9890557707613
#
# Slice number :  68
# No. of points = " 13243 " at 0.12548832 AU
# Vr =  982.2981156109582
#
# Slice number :  69
# No. of points = " 13289 " at 0.12614256000000001 AU
# Vr =  984.5832235150244
#
# Slice number :  70
# No. of points = " 13325 " at 0.1267968 AU
# Vr =  986.8447502410863
#
# Slice number :  71
# No. of points = " 13405 " at 0.12745104 AU
# Vr =  989.0830589344727
#
# Slice number :  72
# No. of points = " 13443 " at 0.12810528 AU
# Vr =  991.2985053221057
#
# Slice number :  73
# No. of points = " 13479 " at 0.12875952000000002 AU
# Vr =  993.4914379009728
#
# Slice number :  74
# No. of points = " 13521 " at 0.12941376 AU
# Vr =  995.6621981208759
#
# Slice number :  75
# No. of points = " 13573 " at 0.13006800000000002 AU
# Vr =  997.8111205616685
#
# Slice number :  76
# No. of points = " 13635 " at 0.13072224 AU
# Vr =  999.9385331051693
#
# Slice number :  77
# No. of points = " 13681 " at 0.13137648000000002 AU
# Vr =  1002.0447571019405
#
# Slice number :  78
# No. of points = " 13709 " at 0.13203072 AU
# Vr =  1004.1301075331037
#
# Slice number :  79
# No. of points = " 13747 " at 0.13268496 AU
# Vr =  1006.1948931673755
#
# Slice number :  80
# No. of points = " 13789 " at 0.1333392 AU
# Vr =  1008.2394167134728
#
# Slice number :  81
# No. of points = " 13845 " at 0.13399344 AU
# Vr =  1010.2639749680571
#
# Slice number :  82
# No. of points = " 13887 " at 0.13464768 AU
# Vr =  1012.268858959366
#
# Slice number :  83
# No. of points = " 13931 " at 0.13530192 AU
# Vr =  1014.2543540866753
#
# Slice number :  84
# No. of points = " 13957 " at 0.13595616 AU
# Vr =  1016.220740255737
#
# Slice number :  85
# No. of points = " 13993 " at 0.1366104 AU
# Vr =  1018.1682920103226
#
# Slice number :  86
# No. of points = " 14047 " at 0.13726464 AU
# Vr =  1020.0972786600083
#
# Slice number :  87
# No. of points = " 14087 " at 0.13791888 AU
# Vr =  1022.0079644043202
#
# Slice number :  88
# No. of points = " 14119 " at 0.13857312 AU
# Vr =  1023.9006084533627
#
# Slice number :  89
# No. of points = " 14155 " at 0.13922736 AU
# Vr =  1025.7754651450487
#
# Slice number :  90
# No. of points = " 14193 " at 0.1398816 AU
# Vr =  1027.6327840590377
#
# Slice number :  91
# No. of points = " 14217 " at 0.14053584 AU
# Vr =  1029.472810127491
#
# Slice number :  92
# No. of points = " 14279 " at 0.14119008 AU
# Vr =  1031.2957837427484
#
# Slice number :  93
# No. of points = " 14313 " at 0.14184432 AU
# Vr =  1033.1019408620275
# Slice number :  94
# No. of points = " 14343 " at 0.14249856 AU
# Vr =  1034.8915131092328
#
# Slice number :  95
# No. of points = " 14373 " at 0.1431528 AU
# Vr =  1036.6647278739804
#
# Slice number :  96
# No. of points = " 14397 " at 0.14380704 AU
# Vr =  1038.421808407913
#
# Slice number :  97
# No. of points = " 14429 " at 0.14446128 AU
# Vr =  1040.162973918402
#
# Slice number :  98
# No. of points = " 14479 " at 0.14511552 AU
# Vr =  1041.8884396597143
#
# Slice number :  99
# No. of points = " 14525 " at 0.14576976 AU
# Vr =  1036.5760440550569
#
# Slice number :  100
# No. of points = " 14551 " at 0.146424 AU
# Vr =  1000.7822809566553
#
# Slice number :  101
# No. of points = " 14583 " at 0.14707824 AU
# Vr =  968.4740552535974
#
# Slice number :  102
# No. of points = " 14603 " at 0.14773248 AU
# Vr =  939.1481443742567
#
# Slice number :  103
# No. of points = " 14629 " at 0.14838672 AU
# Vr =  912.3980350536895
#
# Slice number :  104
# No. of points = " 14659 " at 0.14904096 AU
# Vr =  887.8799603642711
#
# Slice number :  105
# No. of points = " 14695 " at 0.14969520000000003 AU
# Vr =  865.3109350386762
#
# Slice number :  106
# No. of points = " 14735 " at 0.15034944 AU
# Vr =  844.4545158573832
#
# Slice number :  107
# No. of points = " 14779 " at 0.15100367999999997 AU
# Vr =  825.1102670985691
#
# Slice number :  108
# No. of points = " 14793 " at 0.15165792 AU
# Vr =  807.1075517028364
#
# Slice number :  109
# No. of points = " 14821 " at 0.15231216 AU
# Vr =  790.2983937063052
#
# Slice number :  110
# No. of points = " 14845 " at 0.1529664 AU
# Vr =  774.5599871022837
#
# Slice number :  111
# No. of points = " 14873 " at 0.15362063999999997 AU
# Vr =  759.7868756658023
#
# Slice number :  112
# No. of points = " 14903 " at 0.15427488 AU
# Vr =  745.8759890443235
#
# Slice number :  113
# No. of points = " 14939 " at 0.15492912 AU
# Vr =  732.751174311138
#
# Slice number :  114
# No. of points = " 14963 " at 0.15558336 AU
# Vr =  720.3442540743473
#
# Slice number :  115
# No. of points = " 14989 " at 0.15623759999999998 AU
# Vr =  708.5796214974009
#
# Slice number :  116
# No. of points = " 15023 " at 0.15689184 AU
# Vr =  697.4133344170091
#
# Slice number :  117
# No. of points = " 15047 " at 0.15754607999999998 AU
# Vr =  686.7915470163714
#
# Slice number :  118
# No. of points = " 15063 " at 0.15820032 AU
# Vr =  676.6691803393807
#
# Slice number :  119
# No. of points = " 15081 " at 0.15885455999999998 AU
# Vr =  667.0078099352074
#
# Slice number :  120
# No. of points = " 15125 " at 0.1595088 AU
# Vr =  657.7712746108333
#
# Slice number :  121
# No. of points = " 15137 " at 0.16016303999999998 AU
# Vr =  648.9276356427429
#
# Slice number :  122
# No. of points = " 15155 " at 0.16081728 AU
# Vr =  640.4529676646454
#
# Slice number :  123
# No. of points = " 15169 " at 0.16147152 AU
# Vr =  632.3136597273639
#
# Slice number :  124
# No. of points = " 15177 " at 0.16212576 AU
# Vr =  624.6779158648854
#
# Slice number :  125
# No. of points = " 15187 " at 0.16277999999999998 AU
# Vr =  617.7710017056322
#
# Slice number :  126
# No. of points = " 15193 " at 0.16343424 AU
# Vr =  611.4365203737093
#
# Slice number :  127
# No. of points = " 15213 " at 0.16408847999999998 AU
# Vr =  605.5537959135845
#
# Slice number :  128
# No. of points = " 15213 " at 0.16474272 AU
# Vr =  600.0361123720537
#
# Slice number :  129
# No. of points = " 15243 " at 0.16539695999999998 AU
# Vr =  594.8338916836225
#
# Slice number :  130
# No. of points = " 15257 " at 0.1660512 AU
# Vr =  589.9063383436554
#
# Slice number :  131
# No. of points = " 15273 " at 0.16670543999999998 AU
# Vr =  585.2124093424515
#
# Slice number :  132
# No. of points = " 15277 " at 0.16735968 AU
# Vr =  580.7206864794126
#
# Slice number :  133
# No. of points = " 15277 " at 0.16801391999999998 AU
# Vr =  576.4092213649539
#
# Slice number :  134
# No. of points = " 15277 " at 0.16866816 AU
# Vr =  572.2584028254489
#
# Slice number :  135
# No. of points = " 15289 " at 0.16932239999999998 AU
# Vr =  568.2595526816622
#
# Slice number :  136
# No. of points = " 15293 " at 0.16997664 AU
# Vr =  564.3955989456547
#
# Slice number :  137
# No. of points = " 15293 " at 0.17063087999999998 AU
# Vr =  560.6547298922393
#
# Slice number :  138
# No. of points = " 15299 " at 0.17128512 AU
# Vr =  557.0267649333181
#
# Slice number :  139
# No. of points = " 15315 " at 0.17193935999999999 AU
# Vr =  553.503338487167
#
# Slice number :  140
# No. of points = " 15335 " at 0.1725936 AU
# Vr =  550.0768144968614
#
# Slice number :  141
# No. of points = " 15337 " at 0.17324784 AU
# Vr =  546.7403404155873
#
# Slice number :  142
# No. of points = " 15341 " at 0.17390208 AU
# Vr =  543.4881184162504
#
# Slice number :  143
# No. of points = " 15359 " at 0.17455632 AU
# Vr =  540.313806710592
#
# Slice number :  144
# No. of points = " 15359 " at 0.17521056 AU
# Vr =  537.2142908045389
#
# Slice number :  145
# No. of points = " 15357 " at 0.1758648 AU
# Vr =  534.184378591443
#
# Slice number :  146
# No. of points = " 15361 " at 0.17651904000000002 AU
# Vr =  531.219044807684
#
# Slice number :  147
# No. of points = " 15361 " at 0.17717328 AU
# Vr =  528.3162404537718
#
# Slice number :  148
# No. of points = " 15365 " at 0.17782752 AU
# Vr =  525.4725825541005
#
# Slice number :  149
# No. of points = " 15381 " at 0.17848176 AU
# Vr =  522.6845473851217
#
# Slice number :  150
# No. of points = " 15381 " at 0.17913600000000002 AU
# Vr =  519.9492458578393
#
# Slice number :  151
# No. of points = " 15391 " at 0.17979024 AU
# Vr =  517.266910850467
#
# Slice number :  152
# No. of points = " 15403 " at 0.18044448 AU
# Vr =  514.6325856892747
#
# Slice number :  153
# No. of points = " 15397 " at 0.18109872 AU
# Vr =  512.0443819054026
#
# Slice number :  154
# No. of points = " 15403 " at 0.18175296000000002 AU
# Vr =  509.49794708731446
#
# Slice number :  155
# No. of points = " 15415 " at 0.1824072 AU
# Vr =  506.9969764125551
#
# Slice number :  156
# No. of points = " 15419 " at 0.18306144 AU
# Vr =  504.53719638099756
#
# Slice number :  157
# No. of points = " 15419 " at 0.18371568 AU
# Vr =  502.11125004345337
#
# Slice number :  158
# No. of points = " 15417 " at 0.18436991999999996 AU
# Vr =  499.72946645118896
#
# Slice number :  159
# No. of points = " 15429 " at 0.18502416 AU
# Vr =  497.3774534605605
#
# Slice number :  160
# No. of points = " 15429 " at 0.1856784 AU
# Vr =  495.0662879500282
#
# Slice number :  161
# No. of points = " 15437 " at 0.18633264 AU
# Vr =  492.78772789172194
#
# Slice number :  162
# No. of points = " 15449 " at 0.18698688 AU
# Vr =  490.54205795489446
#
# Slice number :  163
# No. of points = " 15451 " at 0.18764112 AU
# Vr =  488.3267529480231
#
# Slice number :  164
# No. of points = " 15451 " at 0.18829536 AU
# Vr =  486.13929648111576
#
# Slice number :  165
# No. of points = " 15449 " at 0.1889496 AU
# Vr =  483.9893676103809
#
# Slice number :  166
# No. of points = " 15467 " at 0.18960384 AU
# Vr =  481.86172312845076
#
# Slice number :  167
# No. of points = " 15471 " at 0.19025808 AU
# Vr =  479.76286428121847
#
# Slice number :  168
# No. of points = " 15465 " at 0.19091232 AU
# Vr =  477.692253769012
#
# Slice number :  169
# No. of points = " 15461 " at 0.19156656 AU
# Vr =  475.6436263932514
#
# Slice number :  170
# No. of points = " 15461 " at 0.1922208 AU
# Vr =  473.62468752977384
#
# Slice number :  171
# No. of points = " 15461 " at 0.19287504 AU
# Vr =  471.63012151438267
#
# Slice number :  172
# No. of points = " 15467 " at 0.19352928 AU
# Vr =  469.65975990531547
#
# Slice number :  173
# No. of points = " 15477 " at 0.19418352 AU
# Vr =  467.7129354405761
#
# Slice number :  174
# No. of points = " 15495 " at 0.19483775999999997 AU
# Vr =  465.78558809670267
#
# Slice number :  175
# No. of points = " 15497 " at 0.195492 AU
# Vr =  463.883879216347
#
# Slice number :  176
# No. of points = " 15501 " at 0.19614623999999997 AU
# Vr =  462.00098665795304
#
# Slice number :  177
# No. of points = " 15503 " at 0.19680047999999997 AU
# Vr =  460.13873332908327
#
# Slice number :  178
# No. of points = " 15509 " at 0.19745472 AU
# Vr =  458.30250599147826
#
# Slice number :  179
# No. of points = " 15517 " at 0.19810896 AU
# Vr =  456.4822234946986
#
# Slice number :  180
# No. of points = " 15511 " at 0.1987632 AU
# Vr =  454.6826992521082
#
# Slice number :  181
# No. of points = " 15517 " at 0.19941744 AU
# Vr =  452.8989263043893
#
# Slice number :  182
# No. of points = " 15523 " at 0.20007167999999997 AU
# Vr =  451.13704235258285
#
# Slice number :  183
# No. of points = " 15525 " at 0.20072592 AU
# Vr =  449.3937519968271
#
# Slice number :  184
# No. of points = " 15523 " at 0.20138015999999997 AU
# Vr =  447.6679369379246
# Slice number :  185
# No. of points = " 15531 " at 0.2020344 AU
# Vr =  445.96001641303576
#
# Slice number :  186
# No. of points = " 15519 " at 0.20268864 AU
# Vr =  444.26906207211954
#
# Slice number :  187
# No. of points = " 15523 " at 0.20334288 AU
# Vr =  442.5947216750369
#
# Slice number :  188
# No. of points = " 15515 " at 0.20399712 AU
# Vr =  440.9339528923049
#
# Slice number :  189
# No. of points = " 15531 " at 0.20465136 AU
# Vr =  439.29181976308075
#
# Slice number :  190
# No. of points = " 15543 " at 0.20530559999999998 AU
# Vr =  437.66596661621645
#
# Slice number :  191
# No. of points = " 15541 " at 0.20595984 AU
# Vr =  436.0552662022899
#
# Slice number :  192
# No. of points = " 15545 " at 0.20661407999999998 AU
# Vr =  434.45955470101546
#
# Slice number :  193
# No. of points = " 15553 " at 0.20726832 AU
# Vr =  432.878651126434
#
# Slice number :  194
# No. of points = " 15559 " at 0.20792255999999998 AU
# Vr =  431.31241641433576
#
# Slice number :  195
# No. of points = " 15561 " at 0.2085768 AU
# Vr =  429.75433600995933
#
# Slice number :  196
# No. of points = " 15569 " at 0.20923103999999998 AU
# Vr =  428.21405846013175
#
# Slice number :  197
# No. of points = " 15575 " at 0.20988527999999995 AU
# Vr =  426.6898716564697
#
# Slice number :  198
# No. of points = " 15575 " at 0.21053951999999998 AU
# Vr =  425.1790606127282
#
# Slice number :  199
# No. of points = " 15577 " at 0.21119376 AU
# Vr =  423.68145750887334
#
# Slice number :  200
# No. of points = " 15569 " at 0.21184799999999998 AU
# Vr =  422.1968765102644
#
# Slice number :  201
# No. of points = " 15573 " at 0.21250224 AU
# Vr =  420.72510824519134
#
# Slice number :  202
# No. of points = " 15583 " at 0.21315647999999998 AU
# Vr =  419.2659127435064
#
# Slice number :  203
# No. of points = " 15581 " at 0.21381072 AU
# Vr =  417.819010373638
#
# Slice number :  204
# No. of points = " 15583 " at 0.21446495999999998 AU
# Vr =  416.38264019218224
#
# Slice number :  205
# No. of points = " 15587 " at 0.2151192 AU
# Vr =  414.95865292871207
#
# Slice number :  206
# No. of points = " 15583 " at 0.21577343999999998 AU
# Vr =  413.55369112438115
#
# Slice number :  207
# No. of points = " 15581 " at 0.21642768 AU
# Vr =  412.15042542884635
#
# Slice number :  208
# No. of points = " 15595 " at 0.21708191999999998 AU
# Vr =  410.763087382312
#
# Slice number :  209
# No. of points = " 15599 " at 0.21773616 AU
# Vr =  409.38802445938984
#
# Slice number :  210
# No. of points = " 15601 " at 0.21839040000000004 AU
# Vr =  408.0207701036953
#
# Slice number :  211
# No. of points = " 15593 " at 0.21904463999999996 AU
# Vr =  406.6657457768203
#
# Slice number :  212
# No. of points = " 15605 " at 0.21969887999999999 AU
# Vr =  405.3215596743335
#
# Slice number :  213
# No. of points = " 15611 " at 0.22035312 AU
# Vr =  403.9876872127117
#
# Slice number :  214
# No. of points = " 15613 " at 0.22100735999999999 AU
# Vr =  402.66283151071855
#
# Slice number :  215
# No. of points = " 15607 " at 0.22166160000000001 AU
# Vr =  401.3499193966835
#
# Slice number :  216
# No. of points = " 15611 " at 0.22231584 AU
# Vr =  400.04703617862134
#
# Slice number :  217
# No. of points = " 15611 " at 0.22297007999999996 AU
# Vr =  398.75396514157666
#
# Slice number :  218
# No. of points = " 15613 " at 0.22362432 AU
# Vr =  397.46975292657595
#
# Slice number :  219
# No. of points = " 15627 " at 0.22427855999999996 AU
# Vr =  396.19778451761965
#
# Slice number :  220
# No. of points = " 15633 " at 0.2249328 AU
# Vr =  394.9331630228064
#
# Slice number :  221
# No. of points = " 15633 " at 0.22558704000000002 AU
# Vr =  393.67702591438615
#
# Slice number :  222
# No. of points = " 15639 " at 0.22624128 AU
# Vr =  392.4308599022736
#
# Slice number :  223
# No. of points = " 15625 " at 0.22689552000000002 AU
# Vr =  391.1941653342478
#
# Slice number :  224
# No. of points = " 15627 " at 0.22754976 AU
# Vr =  389.9667857709616
#
# Slice number :  225
# No. of points = " 15627 " at 0.22820400000000002 AU
# Vr =  388.74634678184134
#
# Slice number :  226
# No. of points = " 15627 " at 0.22885824 AU
# Vr =  387.5405470596586
#
# Slice number :  227
# No. of points = " 15631 " at 0.22951247999999996 AU
# Vr =  386.3355146184625
#
# Slice number :  228
# No. of points = " 15643 " at 0.23016672 AU
# Vr =  385.14310560311515
#
# Slice number :  229
# No. of points = " 15643 " at 0.23082095999999996 AU
# Vr =  383.9588324937832
#
# Slice number :  230
# No. of points = " 15653 " at 0.2314752 AU
# Vr =  382.7827239124164
#
# Slice number :  231
# No. of points = " 15663 " at 0.23212943999999996 AU
# Vr =  381.6152850637064
#
# Slice number :  232
# No. of points = " 15671 " at 0.23278368 AU
# Vr =  380.4553641741374
#
# Slice number :  233
# No. of points = " 15667 " at 0.23343791999999997 AU
# Vr =  379.30397225405403
#
# Slice number :  234
# No. of points = " 15675 " at 0.23409216 AU
# Vr =  378.1600909626815
#
# Slice number :  235
# No. of points = " 15671 " at 0.23474640000000002 AU
# Vr =  377.0242250515721
#
# Slice number :  236
# No. of points = " 15661 " at 0.23540064 AU
# Vr =  375.8949090093528
#
# Slice number :  237
# No. of points = " 15657 " at 0.23605487999999997 AU
# Vr =  374.7740875318152
#
# Slice number :  238
# No. of points = " 15655 " at 0.23670912 AU
# Vr =  373.66394799574147
#
# Slice number :  239
# No. of points = " 15657 " at 0.23736335999999997 AU
# Vr =  372.5578883824327

# %%
images = []
num_frames = 240  # 
os.makedirs(output_dir, exist_ok=True)

for i in range(0,240):
    try:
        Br = np.loadtxt(f"{input_dir}FR_Br_{i}.txt")
        Bt = np.loadtxt(f"{input_dir}FR_Bt_{i}.txt")
        Bp = np.loadtxt(f"{input_dir}FR_Bp_{i}.txt")
        Vr = np.loadtxt(f"{input_dir}FR_Vr_{i}.txt")
        theta_pluto = np.loadtxt(f"{input_dir}FR_theta_{i}.txt")
        phi_pluto = np.loadtxt(f"{input_dir}FR_phi_{i}.txt")
        
        fig, axes = plt.subplots(2, 2, figsize=(10, 8), subplot_kw={'projection': 'polar'})
        fig.suptitle(f"Frame {i+1}")
        
        scatter_params = dict(cmap='viridis', s=10)
        
        valid_phi = (phi_pluto >= 0) & (phi_pluto <= 2 * np.pi)
        invalid_phi = ~valid_phi
        
        sc1 = axes[0, 0].scatter(phi_pluto[valid_phi], theta_pluto[valid_phi], c=Br[valid_phi], vmin=-60, vmax = 60, **scatter_params)
        axes[0, 0].scatter(phi_pluto[invalid_phi], theta_pluto[invalid_phi], color='r', s=10)
        axes[0, 0].set_title("Br")
        plt.colorbar(sc1, ax=axes[0, 0])
        
        sc2 = axes[0, 1].scatter(phi_pluto[valid_phi], theta_pluto[valid_phi], c=Bt[valid_phi], vmin=-60, vmax = 60, **scatter_params)
        axes[0, 1].scatter(phi_pluto[invalid_phi], theta_pluto[invalid_phi], color='r', s=10)
        axes[0, 1].set_title("Bt")
        plt.colorbar(sc2, ax=axes[0, 1])
        
        sc3 = axes[1, 0].scatter(phi_pluto[valid_phi], theta_pluto[valid_phi], c=Bp[valid_phi], vmin=-40, vmax = 40, **scatter_params)
        axes[1, 0].scatter(phi_pluto[invalid_phi], theta_pluto[invalid_phi], color='r', s=10)
        axes[1, 0].set_title("Bp")
        plt.colorbar(sc3, ax=axes[1, 0])
        
        sc4 = axes[1, 1].scatter(phi_pluto[valid_phi], theta_pluto[valid_phi], c=Vr[valid_phi], vmin=600, vmax = 1000, **scatter_params)
        axes[1, 1].scatter(phi_pluto[invalid_phi], theta_pluto[invalid_phi], color='r', s=10)
        axes[1, 1].set_title("Vr")
        plt.colorbar(sc4, ax=axes[1, 1])
        
        plt.tight_layout(rect=[0, 0, 1, 0.96])
        plt.savefig(f"{output_dir_gif}frame_input_{i+1}.png")
        images.append(f"{output_dir_gif}frame_input_{i+1}.png")
        plt.close()
        
        print(f"Saved frame_input_{i+1}.png")
    except Exception as e:
        print(f"Error processing frame {i}: {e}")

frames = [Image.open(f"{output_dir_gif}frame_input_{j}.png") for j in range(1,240)]

frames[0].save(outputgif, save_all=True, append_images=frames[1:],  duration=200, loop=0)
               
print( f"gif saved as {outputgif}")
# Out:
# Saved frame_input_1.png
# Saved frame_input_2.png
# Saved frame_input_3.png
# Saved frame_input_4.png
# Saved frame_input_5.png
# Saved frame_input_6.png
# Saved frame_input_7.png
# Saved frame_input_8.png
# Saved frame_input_9.png
# Saved frame_input_10.png
# Saved frame_input_11.png
# Saved frame_input_12.png
# Saved frame_input_13.png
# Saved frame_input_14.png
# Saved frame_input_15.png
# Saved frame_input_16.png
# Saved frame_input_17.png
# Saved frame_input_18.png
# Saved frame_input_19.png
# Saved frame_input_20.png
# Saved frame_input_21.png
# Saved frame_input_22.png
# Saved frame_input_23.png
# Saved frame_input_24.png
# Saved frame_input_25.png
# Saved frame_input_26.png
# Saved frame_input_27.png
# Saved frame_input_28.png
# Saved frame_input_29.png
# Saved frame_input_30.png
# Saved frame_input_31.png
# Saved frame_input_32.png
# Saved frame_input_33.png
# Saved frame_input_34.png
# Saved frame_input_35.png
# Saved frame_input_36.png
# Saved frame_input_37.png
# Saved frame_input_38.png
# Saved frame_input_39.png
# Saved frame_input_40.png
# Saved frame_input_41.png
# Saved frame_input_42.png
# Saved frame_input_43.png
# Saved frame_input_44.png
# Saved frame_input_45.png
# Saved frame_input_46.png
# Saved frame_input_47.png
# Saved frame_input_48.png
# Saved frame_input_49.png
# Saved frame_input_50.png
# Saved frame_input_51.png
# Saved frame_input_52.png
# Saved frame_input_53.png
# Saved frame_input_54.png
# Saved frame_input_55.png
# Saved frame_input_56.png
# Saved frame_input_57.png
# Saved frame_input_58.png
# Saved frame_input_59.png
# Saved frame_input_60.png
# Saved frame_input_61.png
# Saved frame_input_62.png
# Saved frame_input_63.png
# Saved frame_input_64.png
# Saved frame_input_65.png
# Saved frame_input_66.png
# Saved frame_input_67.png
# Saved frame_input_68.png
# Saved frame_input_69.png
# Saved frame_input_70.png
# Saved frame_input_71.png
# Saved frame_input_72.png
# Saved frame_input_73.png
# Saved frame_input_74.png
# Saved frame_input_75.png
# Saved frame_input_76.png
# Saved frame_input_77.png
# Saved frame_input_78.png
# Saved frame_input_79.png
# Saved frame_input_80.png
# Saved frame_input_81.png
# Saved frame_input_82.png
# Saved frame_input_83.png
# Saved frame_input_84.png
# Saved frame_input_85.png
# Saved frame_input_86.png
# Saved frame_input_87.png
# Saved frame_input_88.png
# Saved frame_input_89.png
# Saved frame_input_90.png
# Saved frame_input_91.png
# Saved frame_input_92.png
# Saved frame_input_93.png
# Saved frame_input_94.png
# Saved frame_input_95.png
# Saved frame_input_96.png
# Saved frame_input_97.png
# Saved frame_input_98.png
# Saved frame_input_99.png
# Saved frame_input_100.png
# Saved frame_input_101.png
# Saved frame_input_102.png
# Saved frame_input_103.png
# Saved frame_input_104.png
# Saved frame_input_105.png
# Saved frame_input_106.png
# Saved frame_input_107.png
# Saved frame_input_108.png
# Saved frame_input_109.png
# Saved frame_input_110.png
# Saved frame_input_111.png
# Saved frame_input_112.png
# Saved frame_input_113.png
# Saved frame_input_114.png
# Saved frame_input_115.png
# Saved frame_input_116.png
# Saved frame_input_117.png
# Saved frame_input_118.png
# Saved frame_input_119.png
# Saved frame_input_120.png
# Saved frame_input_121.png
# Saved frame_input_122.png
# Saved frame_input_123.png
# Saved frame_input_124.png
# Saved frame_input_125.png
# Saved frame_input_126.png
# Saved frame_input_127.png
# Saved frame_input_128.png
# Saved frame_input_129.png
# Saved frame_input_130.png
# Saved frame_input_131.png
# Saved frame_input_132.png
# Saved frame_input_133.png
# Saved frame_input_134.png
# Saved frame_input_135.png
# Saved frame_input_136.png
# Saved frame_input_137.png
# Saved frame_input_138.png
# Saved frame_input_139.png
# Saved frame_input_140.png
# Saved frame_input_141.png
# Saved frame_input_142.png
# Saved frame_input_143.png
# Saved frame_input_144.png
# Saved frame_input_145.png
# Saved frame_input_146.png
# Saved frame_input_147.png
# Saved frame_input_148.png
# Saved frame_input_149.png
# Saved frame_input_150.png
# Saved frame_input_151.png
# Saved frame_input_152.png
# Saved frame_input_153.png
# Saved frame_input_154.png
# Saved frame_input_155.png
# Saved frame_input_156.png
# Saved frame_input_157.png
# Saved frame_input_158.png
# Saved frame_input_159.png
# Saved frame_input_160.png
# Saved frame_input_161.png
# Saved frame_input_162.png
# Saved frame_input_163.png
# Saved frame_input_164.png
# Saved frame_input_165.png
# Saved frame_input_166.png
# Saved frame_input_167.png
# Saved frame_input_168.png
# Saved frame_input_169.png
# Saved frame_input_170.png
# Saved frame_input_171.png
# Saved frame_input_172.png
# Saved frame_input_173.png
# Saved frame_input_174.png
# Saved frame_input_175.png
# Saved frame_input_176.png
# Saved frame_input_177.png
# Saved frame_input_178.png
# Saved frame_input_179.png
# Saved frame_input_180.png
# Saved frame_input_181.png
# Saved frame_input_182.png
# Saved frame_input_183.png
# Saved frame_input_184.png
# Saved frame_input_185.png
# Saved frame_input_186.png
# Saved frame_input_187.png
# Saved frame_input_188.png
# Saved frame_input_189.png
# Saved frame_input_190.png
# Saved frame_input_191.png
# Saved frame_input_192.png
# Saved frame_input_193.png
# Saved frame_input_194.png
# Saved frame_input_195.png
# Saved frame_input_196.png
# Saved frame_input_197.png
# Saved frame_input_198.png
# Saved frame_input_199.png
# Saved frame_input_200.png
# Saved frame_input_201.png
# Saved frame_input_202.png
# Saved frame_input_203.png
# Saved frame_input_204.png
# Saved frame_input_205.png
# Saved frame_input_206.png
# Saved frame_input_207.png
# Saved frame_input_208.png
# Saved frame_input_209.png
# Saved frame_input_210.png
# Saved frame_input_211.png
# Saved frame_input_212.png
# Saved frame_input_213.png
# Saved frame_input_214.png
# Saved frame_input_215.png
# Saved frame_input_216.png
# Saved frame_input_217.png
# Saved frame_input_218.png
# Saved frame_input_219.png
# Saved frame_input_220.png
# Saved frame_input_221.png
# Saved frame_input_222.png
# Saved frame_input_223.png
# Saved frame_input_224.png
# Saved frame_input_225.png
# Saved frame_input_226.png
# Saved frame_input_227.png
# Saved frame_input_228.png
# Saved frame_input_229.png
# Saved frame_input_230.png
# Saved frame_input_231.png
# Saved frame_input_232.png
# Saved frame_input_233.png
# Saved frame_input_234.png
# Saved frame_input_235.png
# Saved frame_input_236.png
# Saved frame_input_237.png
# Saved frame_input_238.png
# Saved frame_input_239.png
# Saved frame_input_240.png
# gif saved as 2290/Input_gif/CME2/Input.gif
